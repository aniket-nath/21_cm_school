# %%
# %matplotlib inline


#essentials
import numpy as np
import pylab as plt
from astropy import units as u
from astropy.coordinates import SkyCoord, EarthLocation, AltAz
import healpy as hp
from datetime import datetime
from pygdsm import GlobalSkyModel
from pygdsm import GSMObserver


#non essential
import time
from tqdm import tqdm
from astropy.coordinates import Angle
import numpy.ma as ma

# %%
gsm = GlobalSkyModel(interpolation='cubic', basemap='haslam')

freq = 150 # MHz unit
gsm.generate(freq)
gsm.view(logged=True)

# %%
gsm = GlobalSkyModel(interpolation='cubic', basemap='wmap')

freq = 150 # MHz unit
gsm.generate(freq)
gsm.view(logged=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 print(f"Angular resolution of the original map: \
# ----> 2 {np.degrees(hp.pixelfunc.nside2resol(hp.pixelfunc.npix2nside(npix))):.2f} degrees")
#       3 print(f"NSIDE of the original map: {hp.pixelfunc.npix2nside(npix)}")
#       4 print(f"Angular resolution: {np.degrees(hp.pixelfunc.nside2resol(NSIDE)):.2f} degrees")
#
# NameError: name 'npix' is not defined
